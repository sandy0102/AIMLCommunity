# %%
#Load the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import pandas_profiling

# %%
#### Step 1: Open the file in your python notebook, print first 5 rows of the dataset and mention what are the dependent and independent variables in the Data.
#Load first five rows
#Load the dataset
df = pd.read_csv('cancer dataset.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
## Dependent variable is Diagnosis which we are going to predict
## Independent variables are all the features except Diagnosis such as id (though this can be dropped later), radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, 
##compactness_mean, concavity_mean,concave points_mean, radius_worst
##texture_worst	perimeter_worst	area_worst, smoothness_worst, compactness_worst	concavity_worst
##concave points_worst	symmetry_worst	fractal_dimension_worst etc

# %%
#### Step 2: Find the statistical parameters of the Data that you have
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
#### Step 3: Find the shape of the Dataset in hand.
df.shape
# Out:
# (569, 32)

# %%
#### Step 4: Find missing values from the Dataset
#### Finding any null values in the dataset
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
#### Finding any NaN values in the dataset
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
#### Step 5: Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis", using dropna = False to see if there are any missing values
df['diagnosis'].value_counts(dropna=False)
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#### Looking at the count, Malignant is 212 and Benign is 357 which means the data is balanced.
#### Also Visualize this count 
sns.countplot(df['diagnosis'],label="Count")

# %%
##label encoding - In this section we encode the categorical data in the cancer dataset by changing the values in the column ‘diagnosis’ from M to 1 and B to 0
from sklearn.preprocessing import LabelEncoder
labelencoder_Y=LabelEncoder()
df.iloc[:,1]=labelencoder_Y.fit_transform(df.iloc[:,1].values)

# %%
#### Step 6: Creating a pairplot  first 5 columns and mention the findings
#### Will drop the first column id later as this column is not of much use so the columns used are diagnosis, radius_mean, texture_mean, 
#### perimeter_mean, area_mean, smoothness_mean
#sns.pairplot(df, vars=['diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean', 'smoothness_mean'],hue='diagnosis')
sns.pairplot(df.iloc[:,1:6],hue='diagnosis')
# Out:
# C:\Users\panduras\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\panduras\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
#### Step 7: Create a correlation matrix and mention strongly, weakly and negatively correlated quantities. We tend to drop features having very strong correlation. Why? Think and try to write the answer.

#Correlation matrix of all the columns
df.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %% [markdown]
# #### Step 7 Part B Mention strongly, weakly and negatively correlated quantities. We tend to drop features having very strong correlation. Why
#
# #### STRONGLY CORRELATED FEATURES
# ###1.diagnosis is strongly correlated with perimeter_worst, area_worst and concave points_worst data points.
# ###2. radius_mean is strongly correlated with area_worst, perimeter_worst and radius_worst
# ###3. texture_mean is strongly correlated with texture_worst
# ###4. perimeter_mean is strongly correlated with area_Worst and perimeter_worst
# ###5. radius_se is strongly correlated with area_se and perimter_se
#
# #### WEAKLY CORRELATED FEATURES
# ###1.symmetry_se is weakly correlated with texture_mean
# ###2.smoothness_mean is weakly correlated with texture_Worst
# ###3.area_se is weakly correlated with symmetry_worst
#
# #### NEGATIVELY CORRELATED FEATURES
# ###1.radius_mean is negatively correlated with fractal_dimension_mean and perimeter_mean
# ###2.area_worst is negatively correlated with fractal_Dimension_mean
# ###3.smoothness_se is negatively correlated with radius_worst
#
# ### We tend to drop features having strong correlation because those features will be more linearly dependant and will have the same effect on the target variable so there is not much use to keep and in feature selection, those features are dropped.

# %%
#### (Optional) Step 8: Create a heatmap of the correlated features (helps in visualization)

plt.figure(figsize=(25,25))  
sns.heatmap(df.corr(), annot=True, fmt='.0%')

# %%
# split the original data into dependent and indepndent variables
X=df.iloc[:,2:31].values #features that help us determine if patient has cancer or not
Y=df.iloc[:,1].values #this is the dataset containing our target variable which indicates diagnosis

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, test_size=0.25, random_state=0)

# %%
#Q1: Now, there is a small homeowrk for statistics wherein you have to read about the parameteres, define them in brief and write about two main types of distributions:
#1. Gaussian distribution
#2. Binomial distribution
#Differentiate between both as well

#***********************************************************************************************************************

#1. Gaussin distribution

# Gaussian distribution is a normal distribution which was discovered by Carl Friedrich Gauss. 
#The normal distribution is a continuous probability distribution also called the bell curve because 
#the graph of its probability density looks like a bell.

#2. Binomial distribution

#A binomial distribution gives the probability of any outcome such as Success or Failure in any experiment even 
#if it is repeated several times.  The prefix 'bi' means two and the binominal distribution is discrete. 
#The parameters are n and p where p denotes the probability distribution of the number of successes in n experiments.


#3 The main difference between normal distribution and binomial distribution is that Binomial distribution is discrete while 
# Normal distribution has continuous data points

# %%
#Q2: Selectively write 5 lines about each of the above three algorithms so that even a rather inexperienced person 
#can understand it alongwith dealing all the technicalities

#**************************************************************************************************************************

#1. Logistics regression 
#Logistic regression is a statistical model which uses a logistic function and builds a model for predicting a binary dependent variable. The dependent variable is categorical in this case. In these type of problems, we need to have a threshold value. In case of a transaction, for example if the predicted value is 0.3 and the threshold value is 0.5, then this data point is classified as Not a fraud transaction.
#Examples can be : 1. To predict whether a transaction is fraud or not 
#				  2. To predict whether the breast cancer is malignant or not. 
#				  3. To predict whether the customer will churn or not
#				  4. Whether the customer will purchase the goods or not
#				  5. Whether the loan application will get approved or not


#2. Decision tree classifier 
#Decision tree learning is one of the popular approaches used in predictive modeling and machine learning. It uses a decision tree to build a predictive model which makes use of a  flow-chart-like structure. In this type of classifier, the topmost node is called the root node and the observations are called the branches and the conclusions about the target values are represented by the leaves. 
#When used for Classification problems, Decision tree analysis is called Decision tree classifier and can be used to predict to which class the data belongs to. 
#Examples can be : 1. To predict whether a transaction is fraud or not 
#				  2. To predict whether the breast cancer is malignant or not. 
#				  3. To predict whether the customer will churn or not
#				  4. Whether the customer will purchase the goods or not
#				  5. Whether the loan application will get approved or not 	


#3. Random Forest classifier 
#Random Forest Classifier is ensemble algorithm which means that this algorithm combines more than one algorithms of same or different kind for the purpose of classificaation. 
#Random forest classifier uses randomly selected subset from the training set and creates a set.  Then votes from different decision trees are taken and aggregated to give the final class of the target object. Random Forest classifier gives more accuracy than an individual tree.

#Examples can be : 1. To predict whether a transaction is fraud or not 
#				  2. To predict whether the breast cancer is malignant or not. 
#				  3. To predict whether the customer will churn or not
#				  4. Whether the customer will purchase the goods or not
#				  5. Whether the loan application will get approved or not

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
##our first model is Logistic Regression
def logreg (X_train, Y_train):
    from sklearn.linear_model import LogisticRegression
    log=LogisticRegression (random_state=0)
    log.fit(X_train, Y_train)
    print("Logistic Regression Training Accuracy:", log.score(X_train, Y_train))
    return log

# %%
logrex=logreg(X_train, Y_train)
# Out:
# Logistic Regression Training Accuracy: 0.9906103286384976
# C:\Users\panduras\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, logrex.predict(X_test))
print(cm)
# Out:
# [[86  4]
#  [ 3 50]]

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print("Testing accuracy of logistic regression model:", (TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing accuracy of logistic regression model: 0.951048951048951

# %%
# Our second model is Decision tree classifier
def logregDT (X_train, Y_train):
    from sklearn.tree import DecisionTreeClassifier
    #dtc = DecisionTreeClassifier(random_state=0)
    dtc = DecisionTreeClassifier(criterion="entropy", max_depth=3,random_state=0)
    dtc.fit(X_train, Y_train)
    print("Decision Tree Training Accuracy:{:.2f}%".format(dtc.score(X_train, Y_train)*100))
    return dtc

# %%
logregDT=logregDT(X_train, Y_train)
# Out:
# Decision Tree Training Accuracy:97.65%

# %%
# Test the model
Y_predict = logregDT.predict(X_test)

# Evaluate the model
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_predict)
print(cm)
# Out:
# [[82  8]
#  [ 2 51]]

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print("Testing accuracy of Decision Tree model:", (TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing accuracy of Decision Tree model: 0.9300699300699301

# %%
##Our third model is Random Forest 
def logregRF(X_train, Y_train):
    from sklearn.ensemble import RandomForestClassifier
    rf = RandomForestClassifier(n_estimators= 1000, random_state = 0)
    rf.fit(X_train, Y_train)
    print("Random Forest Training Accuracy: {:.2f}%".format(rf.score(X_train, Y_train)*100))
    return rf

# %%
logregRF=logregRF(X_train, Y_train)
# Out:
# Random Forest Training Accuracy: 100.00%

# %%
# Test the model
Y_predict = logregRF.predict(X_test)

# %%
## Evaluate the model
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_predict)
print(cm)
# Out:
# [[86  4]
#  [ 1 52]]

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print("Random Forest Testing accuracy =", (TP+TN)/(TP+TN+FN+FP))
# Out:
# Random Forest Testing accuracy = 0.965034965034965

# %%
##Based on the above results, Even though Both Decision Tree and Random forest models are giving 100% accuracy on 
## test data but Random Forest training results are much better than Decision Tree and Logistic Regression
## as it is giving an accuracy of 97% on test data.
